# %%
import sys
import os
sys.path.append(os.path.abspath("../scripts"))

# %%
from ab_test import *

# %%
file_path='../Data/cleaned_data.csv'
df=load_data(file_path)
# Out:
# c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week_3\Alpha_care\scripts\ab_test.py:15: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
perform_ab_tests(df)
# Out:
# Starting A/B Hypothesis Testing...
#
# Missing Values:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                              0
# AccountType                       0
# MaritalStatus                     0
# Gender                            0
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                            0
# VehicleType                       0
# RegistrationYear                  0
# make                              0
# Model                             0
# Cylinders                         0
# ...

# %%
ab_test_zip(df)

# %%
ab_risk_gen(df)
# Out:
# Testing Risk Differences Between Genders:
#
# Comparing Male vs Female:
#
# A/B Test for Total Claims Between Genders:
# T-Statistic: -0.2964, P-Value: 0.7670
# ❌ Fail to Reject Null Hypothesis: No significant difference between groups.
#
# ✅ A/B Testing Completed.
